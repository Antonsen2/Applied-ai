# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import random as r

from PIL import Image

# %%
def plot_samples(images: list, title: str):
    fig, axes = plt.subplots(
            nrows=3,
            ncols=3,
            figsize=(8, 8),
            subplot_kw={'xticks': [], 'yticks': []}
        )

    for i, ax in enumerate(axes.flat):
        image = images[i]
        ax.imshow(image)

    fig.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## DATASET
#
# We took the dataset and sorted the images into __fire__, __non-fire__ and __satellite__ images.<br>
# The CNN-model for the *Image Classification* needs the images to be in the same input-size, so we  resized the images to 250x250 pixels.

# %%
ROOT = 'c:/code/projects/python/applied-ai'  # Changes this locally
DATA_PATH = str(ROOT + '/data/new-data/datasets/full/')

# %% [markdown]
# #### Number of Images

# %%
fire_images = os.listdir(DATA_PATH + 'fire')
nonfire_images = os.listdir(DATA_PATH + 'no-fire')
satellite_images = os.listdir(DATA_PATH + 'satellite')

len(fire_images)
# Out:
# 2071

# %%
X = ['FIRE', 'NON FIRE', 'SATELLITE']
y = [len(fire_images), len(nonfire_images), len(satellite_images)]
cmap = plt.get_cmap('viridis')
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))

fig = plt.figure(figsize=(5,5))

plt.bar(X, y, width=0.9, color=['orange', 'brown', 'green'])
plt.xlabel('Image Class')
plt.ylabel('No. of Images')

fig.suptitle('Number Of Images Per Class')
plt.show()

# %% [markdown]
# #### Sample Images from the dataset

# %%
fire_images = r.sample(os.listdir(DATA_PATH + 'fire'), 9)
nonfire_images = r.sample(os.listdir(DATA_PATH + 'no-fire'), 9)
satellite_images = r.sample(os.listdir(DATA_PATH + 'satellite'), 9)

fire_images
# Out:
# ['fire-1325.jpg',
#  'fire-947.jpg',
#  'fire-1335.jpg',
#  'fire-1725.jpg',
#  'fire-1906.jpg',
#  'fire-1042.jpg',
#  'fire-1440.jpg',
#  'fire-1864.jpg',
#  'fire-339.jpg']

# %%
fire_images = [Image.open(DATA_PATH + 'fire/' + img) for img in fire_images]
nonfire_images = [Image.open(DATA_PATH + 'no-fire/' + img) for img in nonfire_images]
satellite_images = [Image.open(DATA_PATH + 'satellite/' + img) for img in satellite_images]

fire_images
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>]

# %%
plot_samples(fire_images, 'FIRE IMAGES')
plot_samples(nonfire_images, 'NON FIRE IMAGES')
plot_samples(satellite_images, 'SATELLITE IMAGES')
